# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
Train=pd.read_csv('Desktop/train.csv')
Test=pd.read_csv('Desktop/train.csv')

# %%
Train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
Test.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df=Train.append(Test)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2920 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               2920 non-null int64
# MSSubClass       2920 non-null int64
# MSZoning         2920 non-null object
# LotFrontage      2402 non-null float64
# LotArea          2920 non-null int64
# Street           2920 non-null object
# Alley            182 non-null object
# LotShape         2920 non-null object
# LandContour      2920 non-null object
# Utilities        2920 non-null object
# LotConfig        2920 non-null object
# LandSlope        2920 non-null object
# Neighborhood     2920 non-null object
# Condition1       2920 non-null object
# Condition2       2920 non-null object
# BldgType         2920 non-null object
# HouseStyle       2920 non-null object
# OverallQual      2920 non-null int64
# OverallCond      2920 non-null int64
# YearBuilt        2920 non-null int64
# YearRemodAdd     2920 non-null int64
# RoofStyle        2920 non-null object
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      518
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  2920.000000  2920.000000  2402.000000    2920.000000  2920.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.537785    42.293325    24.279694    9979.555080     1.382760
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  2920.000000  2920.000000   2920.000000  2904.000000  2920.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112609    30.197730     20.641870   181.035018   456.019958  ...
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
df.boxplot(rot=90,figsize=(15,20))

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data=df.isnull(),cmap='viridis')

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,linewidths=.5)

# %%
plt.hist(df['SalePrice'])
# Out:
# (array([ 296., 1446.,  746.,  270.,  102.,   38.,    8.,    6.,    4.,
#            4.]),
#  array([ 34900., 106910., 178920., 250930., 322940., 394950., 466960.,
#         538970., 610980., 682990., 755000.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df['SalePrice'],bins=100)
plt.xlabel('price')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
df.drop(['Alley','FireplaceQu','PoolQC','Fence','MiscFeature','Id'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2920 entries, 0 to 1459
# Data columns (total 75 columns):
# MSSubClass       2920 non-null int64
# MSZoning         2920 non-null object
# LotFrontage      2402 non-null float64
# LotArea          2920 non-null int64
# Street           2920 non-null object
# LotShape         2920 non-null object
# LandContour      2920 non-null object
# Utilities        2920 non-null object
# LotConfig        2920 non-null object
# LandSlope        2920 non-null object
# Neighborhood     2920 non-null object
# Condition1       2920 non-null object
# Condition2       2920 non-null object
# BldgType         2920 non-null object
# HouseStyle       2920 non-null object
# OverallQual      2920 non-null int64
# OverallCond      2920 non-null int64
# YearBuilt        2920 non-null int64
# YearRemodAdd     2920 non-null int64
# RoofStyle        2920 non-null object
# RoofMatl         2920 non-null object
# Exterior1st      2920 non-null object
# ...

# %%
df['LotFrontage'].fillna(value=df['LotFrontage'].mean(),inplace=True)

# %%
df.drop(['GarageType','GarageYrBlt','GarageFinish','GarageQual','GarageCond'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2920 entries, 0 to 1459
# Data columns (total 70 columns):
# MSSubClass       2920 non-null int64
# MSZoning         2920 non-null object
# LotFrontage      2920 non-null float64
# LotArea          2920 non-null int64
# Street           2920 non-null object
# LotShape         2920 non-null object
# LandContour      2920 non-null object
# Utilities        2920 non-null object
# LotConfig        2920 non-null object
# LandSlope        2920 non-null object
# Neighborhood     2920 non-null object
# Condition1       2920 non-null object
# Condition2       2920 non-null object
# BldgType         2920 non-null object
# HouseStyle       2920 non-null object
# OverallQual      2920 non-null int64
# OverallCond      2920 non-null int64
# YearBuilt        2920 non-null int64
# YearRemodAdd     2920 non-null int64
# RoofStyle        2920 non-null object
# RoofMatl         2920 non-null object
# Exterior1st      2920 non-null object
# ...

# %%
df.dropna(inplace=True)

# %%
sns.heatmap(data=df.isnull())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2824 entries, 0 to 1459
# Data columns (total 70 columns):
# MSSubClass       2824 non-null int64
# MSZoning         2824 non-null object
# LotFrontage      2824 non-null float64
# LotArea          2824 non-null int64
# Street           2824 non-null object
# LotShape         2824 non-null object
# LandContour      2824 non-null object
# Utilities        2824 non-null object
# LotConfig        2824 non-null object
# LandSlope        2824 non-null object
# Neighborhood     2824 non-null object
# Condition1       2824 non-null object
# Condition2       2824 non-null object
# BldgType         2824 non-null object
# HouseStyle       2824 non-null object
# OverallQual      2824 non-null int64
# OverallCond      2824 non-null int64
# YearBuilt        2824 non-null int64
# YearRemodAdd     2824 non-null int64
# RoofStyle        2824 non-null object
# RoofMatl         2824 non-null object
# Exterior1st      2824 non-null object
# ...

# %%
df_numeric_features=df.select_dtypes(include=[np.number])
df_numeric_features.columns
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
df_numeric_features
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %%
df_categorical_features=df.select_dtypes(include=[np.object])

# %%
df_categorical_features.columns
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
def category_onehot_multcols(multcolumns):
    df_final=df
    i=0
    for fields in multcolumns:
        
        print(fields)
        df1=pd.get_dummies(df[fields],drop_first=True)
        
        df.drop([fields],axis=1,inplace=True)
        if i==0:
            df_final=df1.copy()
        else:
            
            df_final=pd.concat([df_final,df1],axis=1)
        i=i+1
       
        
    df_final=pd.concat([df,df_final],axis=1)
        
    return df_final

# %%
final_df=category_onehot_multcols(df_categorical_features.columns)
# Out:
# MSZoning
# Street
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# PavedDrive
# SaleType
# SaleCondition

# %%
final_df.shape
# Out:
# (2824, 213)

# %%
final_df =final_df.loc[:,~final_df.columns.duplicated()]

# %%
final_df.shape
# Out:
# (2824, 167)

# %%
final_df.isnull().sum()
# Out:
# MSSubClass     0
# LotFrontage    0
# LotArea        0
# OverallQual    0
# OverallCond    0
#               ..
# AdjLand        0
# Alloca         0
# Family         0
# Normal         0
# Partial        0
# Length: 167, dtype: int64

# %%
X=final_df.drop('SalePrice',axis=1)
y=final_df['SalePrice']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2824 entries, 0 to 1459
# Columns: 166 entries, MSSubClass to Partial
# dtypes: float64(2), int64(33), uint8(131)
# memory usage: 1.1 MB

# %%
y.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.11, random_state=31)

# %%
X_train.isnull().sum()
# Out:
# MSSubClass     0
# LotFrontage    0
# LotArea        0
# OverallQual    0
# OverallCond    0
#               ..
# AdjLand        0
# Alloca         0
# Family         0
# Normal         0
# Partial        0
# Length: 166, dtype: int64

# %%
X_train.head()
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 1439          60    80.000000    11584            7            6       1979
# 1028          50    79.000000     9492            5            5       1941
# 910           90    80.000000    11600            5            5       1960
# 593          120    70.049958     4435            6            5       2003
# 974           70    60.000000    11414            7            8       1910
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  ConLI  ConLw  \
# 1439          1979        96.0         315         110  ...      0      0
# 1028          1950         0.0         368          41  ...      0      0
# 910           1960       361.0         443           0  ...      0      0
# 593           2003       170.0         685           0  ...      0      0
# 974           1993         0.0           0           0  ...      0      0
#
#       New  Oth  WD  AdjLand  Alloca  Family  Normal  Partial
# ...

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 311 entries, 1123 to 951
# Columns: 166 entries, MSSubClass to Partial
# dtypes: float64(2), int64(33), uint8(131)
# memory usage: 127.3 KB

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2513 entries, 1439 to 744
# Columns: 166 entries, MSSubClass to Partial
# dtypes: float64(2), int64(33), uint8(131)
# memory usage: 1.0 MB

# %%
from sklearn import linear_model

# %%
lm=linear_model.LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.intercept_
# Out:
# -1596022.1147516384

# %%
lm.coef_
# Out:
# array([-1.08658122e+02,  4.76522587e+01,  4.16568054e-01,  7.78949881e+03,
#         5.83005445e+03,  2.90568641e+02,  1.08530418e+02,  1.34849436e+01,
#         1.80793568e+01,  6.00049052e+00, -1.77102312e+00,  2.23088241e+01,
#         1.04052179e+01,  3.30500550e+01, -8.02615732e+00,  3.54292492e+01,
#         3.09290829e+03, -6.30372269e+01,  1.79933002e+03,  1.05283065e+03,
#        -4.26077646e+03, -1.70808147e+04,  2.16706260e+03,  4.68819104e+03,
#         5.33459209e+03,  6.99577927e+00,  9.28572951e+00,  1.64868008e+00,
#         2.96907897e+00,  5.19456363e+01,  3.29465411e+01,  9.21372824e+01,
#        -2.36766848e+00, -5.48003173e+02,  4.93964755e+01,  2.83556976e+04,
#         2.10605433e+04,  2.45097931e+04,  2.17228064e+04,  3.57696050e+04,
#         9.43713584e+03,  7.35248181e+03,  5.71610682e+02,  1.76983188e+04,
#         6.54923446e+02,  1.29026965e+04, -3.91999530e+04,  8.90347512e+03,
# ...

# %%
X.columns
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        ...
#        'ConLI', 'ConLw', 'New', 'Oth', 'WD', 'AdjLand', 'Alloca', 'Family',
#        'Normal', 'Partial'],
#       dtype='object', length=166)

# %%
coeff=pd.DataFrame(data=lm.coef_,index=X.columns,columns=['Coeficients'])

# %%
coeff.head()
# Out:
#              Coeficients
# MSSubClass   -108.658122
# LotFrontage    47.652259
# LotArea         0.416568
# OverallQual  7789.498812
# OverallCond  5830.054449

# %%
pred=lm.predict(X_test)
pred
# Out:
# array([103043.83782293,  69257.54745881, 168247.67099843, 168621.86153822,
#        220184.59052106, 151664.35978378, 141115.48205839, 117980.63285454,
#        177817.3590489 , 185592.34470988, 126655.99019535, 305269.12835235,
#        330783.09360593, 105137.15519146,  69653.68997778, 196552.17244558,
#        124279.11359651, 182336.97451921, 171664.41086134, 166823.55003349,
#        249858.76752924, 261534.27961952, 125735.86351883, 137800.51996651,
#        202077.84710309, 104472.40909473, 164778.94178725, 263362.09675827,
#        190273.4583024 , 213797.7471449 , 238675.76789193, 136763.25774846,
#        111459.24969165, 285020.81632075, 210366.27609517, 304469.83066447,
#        148325.54480683, 168927.81730888, 122944.1533923 , 153364.32977613,
#        141995.77779395, 192695.87005841, 122237.24115655, 273435.20050634,
#        223232.81474539, 299573.57889167, 102517.92072233,  86705.95742413,
# ...

# %%
y_test
# Out:
# 1123    118000
# 107     115000
# 1299    154000
# 997     185000
# 337     214000
#          ...
# 128     155000
# 599     151000
# 430      85400
# 366     159000
# 951     119900
# Name: SalePrice, Length: 311, dtype: int64

# %%
plt.scatter(y_test,pred)

# %%
sns.distplot(y_test-pred)

# %%
from sklearn import metrics

# %%
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# RMSE: 25769.130295605395

# %%
print('Acuracy is ',end='')
print(lm.score(X_test,y_test)*100)
# Out:
# Acuracy is 91.11898021175364
